# %% [markdown]
# # CNN-RNN

# %%
import torch
from torch.utils.data import Dataset
import pandas as pd
import pytz
import numpy as np
import os
import sys
import glob
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader
from datetime import datetime
import matplotlib.pyplot as plt
import re
from sklearn.metrics import precision_score, recall_score, f1_score
from torch.utils.data import ConcatDataset, TensorDataset


scripts_dir = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
sys.path.append(scripts_dir)
from data_generator import normalize_new_data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
torch.set_default_device(device)
# Out:
# cuda

# %%
# Define the directory and base filename pattern
file_pattern = "../data/final_data/cleaned_compiled_data_normalized_part*.csv"

# Use glob to get a sorted list of all matching CSV parts
csv_files = sorted(glob.glob(file_pattern))

# Load and concatenate all parts
data = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)

# Done! Now `data` holds the full combined normalized DataFrame
print(f"Loaded {len(csv_files)} files. Final shape: {data.shape}")
# Out:
# Loaded 2 files. Final shape: (300282, 37)

# %%
chosen_stations = ['S104', 'S107', 'S109', 'S115', 'S116', 'S43', 'S50']
pixel_coords = [(4, 11, 'S109'),
 (2, 7, 'S50'),
 (1, 16, 'S107'),
 (2, 13, 'S43'),
 (0, 0, 'S115'),
 (0, 6, 'S116'),
 (8, 8, 'S104')]
def tabular_to_image(data: pd.DataFrame, pixel_coords, image_shape=(9, 18)):
    feature_types = ['rainfall', 'air_temperature', 'wind_speed', 'relative_humidity', 'wind_direction']
    H, W = image_shape
    T = data.shape[0]
    image = np.full((T, H, W, len(feature_types)), np.nan, dtype=np.float32)

    feature_to_channel = {feat: i for i, feat in enumerate(feature_types)}

    for y, x, station_id in pixel_coords:
        for feat in feature_types:
            col_name = f"{feat}_{station_id}"
            if col_name in data.columns:
                channel = feature_to_channel[feat]
                image[:, y, x, channel] = data[col_name].values

    return image if T > 1 else image[0]

# %%
class LightningDataset_Modified(Dataset):
    def __init__(self, compiled_df, pixel_coords, image_shape=(9, 18), timezone_str="Asia/Singapore", reject_zeros=True):
        self.compiled_df = compiled_df.copy()
        self.pixel_coords = pixel_coords
        self.image_shape = image_shape
        self.timezone = pytz.timezone(timezone_str)
        self.samples = []
        self.reject_zeros = reject_zeros
        self.rejected_samples = []

        self._prepare_dataset()

    def _prepare_dataset(self):
        # Ensure datetime index
        self.compiled_df["Timestamp"] = pd.to_datetime(self.compiled_df["Timestamp"])
        if not isinstance(self.compiled_df.index, pd.DatetimeIndex):
            self.compiled_df.set_index("Timestamp", inplace=True)
        self.compiled_df.index = self.compiled_df.index.tz_localize(None)

        # Drop target for input features
        input_df = self.compiled_df.drop(columns=["Lightning_Risk"])

        # Valid 2-hour timestamps
        min_ts = self.compiled_df.index.min().ceil("2h") + pd.Timedelta(hours=2)
        max_ts = self.compiled_df.index.max().floor("2h")
        valid_ts = self.compiled_df.loc[
            (self.compiled_df.index >= min_ts) &
            (self.compiled_df.index <= max_ts) &
            (self.compiled_df.index.hour % 2 == 0) &
            (self.compiled_df.index.minute == 0)
        ].index
        #semi_reject = True
        for timestamp in valid_ts:
            try:
                # Input time windows (past 5)
                input_times = [timestamp - pd.Timedelta(minutes=delta) for delta in [120, 90, 60, 30, 0]]
                input_slices = self.compiled_df.loc[input_times]
                input_images = tabular_to_image(input_slices, self.pixel_coords, self.image_shape)  # (5, H, W, C)

                # Rearrange to (C, T, H, W) if needed
                input_tensor = np.transpose(input_images, (3, 0, 1, 2))  # (C, T, H, W)

                # Output time windows (future 5)
                output_times = [timestamp + pd.Timedelta(minutes=delta) for delta in [0, 30, 60, 90, 120]]
                output_data = self.compiled_df.loc[output_times, "Lightning_Risk"].astype(int).values.flatten()
                
                if self.reject_zeros and not (output_data == 1).any():
                    #semi_reject = not semi_reject  # Reject half of dataset with only zeros
                    #if semi_reject:
                        # Convert rejected samples to tensor and append
                    input_tensor = torch.tensor(input_tensor, dtype=torch.float32)
                    output_data = torch.tensor(output_data, dtype=torch.float32)
                    self.rejected_samples.append((input_tensor, output_data))
                    continue
                     
                # Store valid samples
                self.samples.append((torch.tensor(input_tensor, dtype=torch.float32), torch.tensor(output_data, dtype=torch.float32)))

            except KeyError:
                continue  # Skip if any timestamps are missing

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]

        # Format input shape for model: (C, T, H, W) → (T, C, H, W)
        x = x.permute(1, 0, 2, 3)

        return x, y

    def get_positive_ratio(self):
        all_labels = np.array([sample[1] for sample in self.samples])  # shape (N, 5)
        total = all_labels.size
        positives = (all_labels == 1).sum()
        return positives / total

    def get_rejected_samples(self):
        # Separate input tensors and output tensors from the rejected_samples
        inputs, outputs = zip(*self.rejected_samples)
        
        # Convert the list of inputs and outputs into tensors
        input_tensor = torch.stack(inputs)
        output_tensor = torch.stack(outputs)
        
        # Return a TensorDataset containing both inputs and outputs
        return torch.utils.data.TensorDataset(input_tensor, output_tensor)

# %%
dataset = LightningDataset_Modified(data,pixel_coords,reject_zeros=True)

# %%
dataset[0]
# Out:
# (tensor([[[[0.0000,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.0000,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.6852,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6116,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4987,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.5893,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4730,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.5622,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.9477,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4878,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]],
#
#
#          [[[0.0000,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.0000,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.7088,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6241,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.5055,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6358,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4569,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.5449,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.9354,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4614,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]],
#
#
#          [[[0.0000,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.0000,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.7030,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6366,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4987,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6635,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4650,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.5674,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.9675,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4522,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]],
#
#
#          [[[0.0000,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.0000,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.6911,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6427,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.5502,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6619,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4812,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.5604,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.9354,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4762,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]],
#
#
#          [[[0.0000,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.0000,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.7147,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6611,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4987,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.6283,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.4730,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4960,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#           [[0.9538,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan, 0.4674,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            ...,
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#            [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]]],
#         device='cuda:0'),
#  tensor([0., 1., 1., 1., 1.], device='cuda:0'))

# %%
len(dataset)
# Out:
# 1528

# %%
def get_positive_ratio(samples):
    # Move the labels to CPU if they are on a GPU
    all_labels = np.array([sample[1].cpu().numpy() for sample in samples])  # shape (N, 5)
    
    total = all_labels.size
    positives = (all_labels == 1).sum()

    positive_ratio = positives / total
    return positive_ratio

# %%
len(dataset)
# Out:
# 1528

# %%
# Set seed for reproducibility
g = torch.Generator(device).manual_seed(42)
train_ratio = 0.8
# Calculate split sizes
train_size = int(train_ratio* len(dataset))
val_size = len(dataset) - train_size

# Randomly split the dataset
train_dataset, val_dataset = random_split(dataset, [train_size, val_size], generator=g)

rejected_dataset = dataset.get_rejected_samples()
rejected_num = len(rejected_dataset)
print("Rejected samples:", rejected_num)

# Generate a shuffled list of indices (optional but recommended for randomness)
rejected_indices = torch.randperm(rejected_num, generator=g)

# Split indices based on ratio
train_split_idx = int(train_ratio*0.6 * rejected_num)
train_indices = rejected_indices[:train_split_idx]
val_indices = rejected_indices[train_split_idx:]

# Create Subsets
rejected_train = torch.utils.data.Subset(rejected_dataset, train_indices)
rejected_val = torch.utils.data.Subset(rejected_dataset, val_indices)

# Concatenate with original datasets
train_dataset = torch.utils.data.ConcatDataset([train_dataset, rejected_train])
val_dataset = torch.utils.data.ConcatDataset([val_dataset, rejected_val])

# Create DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True, generator=g)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=False)
# Out:
# Rejected samples: 10343

# %%
train_p_r = get_positive_ratio(train_dataset)
print(train_p_r)
# Out:
# 0.0930164888457808

# %%
class LightningRiskCNNRNN(nn.Module):
    def __init__(self, num_channels=5, num_future_steps=5, hidden_size=256):
        super(LightningRiskCNNRNN, self).__init__()

        # --- CNN Feature Extractor ---
        self.conv1 = nn.Conv2d(in_channels=num_channels, out_channels=32, kernel_size=5, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=5, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.flatten = nn.Flatten()

        # Dynamically determine CNN output size
        with torch.no_grad():
            dummy_input = torch.zeros(1, num_channels, 9, 18)
            x = F.relu(self.conv1(dummy_input))
            x = F.relu(self.conv2(x))
            x = F.relu(self.conv3(x))
            self.feature_size = self.flatten(x).shape[1]

        # --- RNN ---
        self.rnn = nn.RNN(input_size=self.feature_size, hidden_size=hidden_size, batch_first=True)

        # --- Output Layer ---
        self.fc = nn.Linear(hidden_size, num_future_steps)

        # --- Learnable initial hidden state ---
        self.initial_hidden_state = nn.Parameter(torch.randn(1, 1, hidden_size))

    def forward(self, x):
        # x: (batch_size, seq_len=5, channels=5, height, width)
        batch_size, seq_len, c, h, w = x.shape

        cnn_features = []
        for t in range(seq_len):
            x_t = x[:, t]  # (batch, channels, height, width)
            x_t = torch.nan_to_num(x_t, nan=0.0)

            out = F.relu(self.conv1(x_t))
            out = F.relu(self.conv2(out))
            out = F.relu(self.conv3(out))
            out = self.flatten(out)

            cnn_features.append(out)

        cnn_features = torch.stack(cnn_features, dim=1)  # (batch_size, seq_len, feature_size)

        # Expand learnable hidden state for batch
        h0 = self.initial_hidden_state.expand(1, batch_size, -1).contiguous()

        # RNN
        rnn_out, _ = self.rnn(cnn_features, h0)

        # Final hidden state
        final_hidden = rnn_out[:, -1, :]  # (batch_size, hidden_size)

        # Risk prediction without sigmoid (for BCEWithLogitsLoss)
        predictions = self.fc(final_hidden)  # (batch_size, num_future_steps)

        return predictions

# %%
for i in range(len(train_dataset)):
    x, y = train_dataset[i]
    if x.shape != (5, x.shape[1], x.shape[2], x.shape[3]):  # Assuming T=5 fixed
        print(f"Sample {i} has unexpected x shape: {x.shape}")
    if y.shape != torch.Size([5]):
        print(f"Sample {i} has unexpected y shape: {y.shape}")

# %%
model = LightningRiskCNNRNN().to(device)
# Get one batch
for batch_x, batch_y in train_dataloader:
    batch_x = batch_x.to(device)
    batch_y = batch_y.to(device)

# %%
def train(dataloader, model, num_epochs, learning_rate, device=device, train_p_r=train_p_r):
    model.train()
    model.to(device)  # Ensure model is on GPU/CPU

    # Binary Cross Entropy Loss for multi-label binary outputs
    
    #criterion = nn.BCELoss()
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([train_p_r]).to(device)) #make sure no sigmoid on the other side
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # List to track the average loss for every epoch (including epoch 0)
    avg_loss_history = []

    os.makedirs("models", exist_ok=True)  # Ensure the directory exists
    timestamp = datetime.now().strftime('%Y_%m_%d_%H_%M')
    for epoch in range(num_epochs):
        total_loss = 0
        for inputs, targets in dataloader:
            inputs = inputs.to(device)   # (B, T, C, H, W)
            targets = targets.to(device)  # (B, 5) — each value ∈ [0, 1]

            optimizer.zero_grad()

            predictions = model(inputs)  # Output shape: (B, 5)

            loss = criterion(predictions, targets)
            total_loss += loss.item()

            loss.backward()
            optimizer.step()

        # Calculate average loss for the epoch
        avg_loss = total_loss / len(dataloader)

        # Save the average loss every 5 epochs for monitoring
        if (epoch) % 5 == 0:
            avg_loss_history.append(avg_loss)
            print(f"Epoch {epoch+1}/{num_epochs} - Avg Loss: {avg_loss:.4f}")

        if (epoch) % 20 == 0:
            filename = f'model_{timestamp}_{avg_loss:0.6f}_{epoch}.pth'
            torch.save(model.state_dict(), os.path.join("models", filename))
            print(f"Model saved as {filename}")
    final_filename = f'model_{timestamp}_{avg_loss:0.6f}_{num_epochs-1}.pth'
    torch.save(model.state_dict(), os.path.join("models", final_filename))
    print(f"Final model saved as {final_filename}")

    # Save the model with timestamp and final loss at the end of training
    final_loss = avg_loss_history[-1] if avg_loss_history else 0
    
    filename = f'model_{timestamp}_{final_loss:0.6f}.pth'

    # Save model state
    
    torch.save(model.state_dict(), os.path.join("models", filename))
    print(f"Model saved as {filename}")

    # Plotting the average loss every epoch (including epoch 0) in two subplots
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    # Plot with standard y-axis
    axs[0].plot(range(0,num_epochs,5), avg_loss_history, label='Average Loss (every epoch)', color='blue')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].set_title('Average Training Loss Over Time (Standard Y-Axis)')
    axs[0].grid(True)
    axs[0].legend()

    # Plot with logarithmic y-axis
    axs[1].plot(range(0,num_epochs,5), avg_loss_history, label='Average Loss (every epoch)', color='blue')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_title('Average Training Loss Over Time (Logarithmic Y-Axis)')
    axs[1].set_yscale('log')  # Set the y-axis to logarithmic scale
    axs[1].grid(True)
    axs[1].legend()

    # Save the plot as an image
    os.makedirs("plots", exist_ok=True)  # Ensure the directory exists
    plot_filename = f'loss_plot_{timestamp}.png'
    plt.savefig(os.path.join("plots", plot_filename))
    print(f"Plot saved as {plot_filename}")

    # Show the plot
    plt.show()

    return avg_loss_history  # Return the loss history

# %%
model = LightningRiskCNNRNN().to(device)
# %timeit -r 1 -n 1 train(dataloader = train_dataloader, model = model, num_epochs = 1000, learning_rate = 1e-4)
# Out:
# Epoch 1/1000 - Avg Loss: 0.1181
# Model saved as model_2025_04_19_01_16_0.118102_0.pth
# Epoch 6/1000 - Avg Loss: 0.0428
# Epoch 11/1000 - Avg Loss: 0.0315
# Epoch 16/1000 - Avg Loss: 0.0294
# Epoch 21/1000 - Avg Loss: 0.0283
# Model saved as model_2025_04_19_01_16_0.028349_20.pth
# Epoch 26/1000 - Avg Loss: 0.0414
# Epoch 31/1000 - Avg Loss: 0.0280
# Epoch 36/1000 - Avg Loss: 0.0272
# Epoch 41/1000 - Avg Loss: 0.0269
# Model saved as model_2025_04_19_01_16_0.026859_40.pth
# Epoch 46/1000 - Avg Loss: 0.0267
# Epoch 51/1000 - Avg Loss: 0.0264
# Epoch 56/1000 - Avg Loss: 0.0260
# Epoch 61/1000 - Avg Loss: 0.0259
# Model saved as model_2025_04_19_01_16_0.025900_60.pth
# Epoch 66/1000 - Avg Loss: 0.0255
# Epoch 71/1000 - Avg Loss: 0.0253
# Epoch 76/1000 - Avg Loss: 0.0248
# Epoch 81/1000 - Avg Loss: 0.0249
# Model saved as model_2025_04_19_01_16_0.024893_80.pth
# Epoch 86/1000 - Avg Loss: 0.0242
# Epoch 91/1000 - Avg Loss: 0.0238
# Epoch 96/1000 - Avg Loss: 0.0234
# Epoch 101/1000 - Avg Loss: 0.0230
# Model saved as model_2025_04_19_01_16_0.023004_100.pth
# Epoch 106/1000 - Avg Loss: 0.0227
# Epoch 111/1000 - Avg Loss: 0.0221
# Epoch 116/1000 - Avg Loss: 0.0216
# Epoch 121/1000 - Avg Loss: 0.0209
# Model saved as model_2025_04_19_01_16_0.020938_120.pth
# Epoch 126/1000 - Avg Loss: 0.0204
# Epoch 131/1000 - Avg Loss: 0.0198
# Epoch 136/1000 - Avg Loss: 0.0192
# Epoch 141/1000 - Avg Loss: 0.0184
# Model saved as model_2025_04_19_01_16_0.018425_140.pth
# Epoch 146/1000 - Avg Loss: 0.0178
# Epoch 151/1000 - Avg Loss: 0.0169
# Epoch 156/1000 - Avg Loss: 0.0163
# Epoch 161/1000 - Avg Loss: 0.0154
# Model saved as model_2025_04_19_01_16_0.015352_160.pth
# Epoch 166/1000 - Avg Loss: 0.0145
# Epoch 171/1000 - Avg Loss: 0.0140
# Epoch 176/1000 - Avg Loss: 0.0130
# Epoch 181/1000 - Avg Loss: 0.0121
# Model saved as model_2025_04_19_01_16_0.012068_180.pth
# Epoch 186/1000 - Avg Loss: 0.0116
# Epoch 191/1000 - Avg Loss: 0.0112
# Epoch 196/1000 - Avg Loss: 0.0105
# Epoch 201/1000 - Avg Loss: 0.0100
# Model saved as model_2025_04_19_01_16_0.010046_200.pth
# Epoch 206/1000 - Avg Loss: 0.0093
# Epoch 211/1000 - Avg Loss: 0.0092
# Epoch 216/1000 - Avg Loss: 0.0081
# Epoch 221/1000 - Avg Loss: 0.0074
# Model saved as model_2025_04_19_01_16_0.007360_220.pth
# Epoch 226/1000 - Avg Loss: 0.0069
# Epoch 231/1000 - Avg Loss: 0.0065
# Epoch 236/1000 - Avg Loss: 0.0057
# Epoch 241/1000 - Avg Loss: 0.0056
# Model saved as model_2025_04_19_01_16_0.005588_240.pth
# Epoch 246/1000 - Avg Loss: 0.0055
# Epoch 251/1000 - Avg Loss: 0.0046
# Epoch 256/1000 - Avg Loss: 0.0045
# Epoch 261/1000 - Avg Loss: 0.0036
# Model saved as model_2025_04_19_01_16_0.003574_260.pth
# Epoch 266/1000 - Avg Loss: 0.0034
# Epoch 271/1000 - Avg Loss: 0.0033
# Epoch 276/1000 - Avg Loss: 0.0041
# Epoch 281/1000 - Avg Loss: 0.0029
# Model saved as model_2025_04_19_01_16_0.002904_280.pth
# Epoch 286/1000 - Avg Loss: 0.0025
# Epoch 291/1000 - Avg Loss: 0.0035
# Epoch 296/1000 - Avg Loss: 0.0020
# Epoch 301/1000 - Avg Loss: 0.0018
# Model saved as model_2025_04_19_01_16_0.001848_300.pth
# Epoch 306/1000 - Avg Loss: 0.0031
# Epoch 311/1000 - Avg Loss: 0.0016
# Epoch 316/1000 - Avg Loss: 0.0015
# Epoch 321/1000 - Avg Loss: 0.0018
# Model saved as model_2025_04_19_01_16_0.001837_320.pth
# Epoch 326/1000 - Avg Loss: 0.0012
# Epoch 331/1000 - Avg Loss: 0.0018
# Epoch 336/1000 - Avg Loss: 0.0022
# Epoch 341/1000 - Avg Loss: 0.0010
# Model saved as model_2025_04_19_01_16_0.001004_340.pth
# Epoch 346/1000 - Avg Loss: 0.0009
# Epoch 351/1000 - Avg Loss: 0.0008
# Epoch 356/1000 - Avg Loss: 0.0031
# Epoch 361/1000 - Avg Loss: 0.0007
# Model saved as model_2025_04_19_01_16_0.000742_360.pth
# Epoch 366/1000 - Avg Loss: 0.0006
# Epoch 371/1000 - Avg Loss: 0.0027
# Epoch 376/1000 - Avg Loss: 0.0007
# Epoch 381/1000 - Avg Loss: 0.0006
# Model saved as model_2025_04_19_01_16_0.000575_380.pth
# Epoch 386/1000 - Avg Loss: 0.0065
# Epoch 391/1000 - Avg Loss: 0.0006
# Epoch 396/1000 - Avg Loss: 0.0005
# Epoch 401/1000 - Avg Loss: 0.0005
# Model saved as model_2025_04_19_01_16_0.000462_400.pth
# Epoch 406/1000 - Avg Loss: 0.0008
# Epoch 411/1000 - Avg Loss: 0.0011
# Epoch 416/1000 - Avg Loss: 0.0004
# Epoch 421/1000 - Avg Loss: 0.0003
# Model saved as model_2025_04_19_01_16_0.000342_420.pth
# Epoch 426/1000 - Avg Loss: 0.0003
# Epoch 431/1000 - Avg Loss: 0.0013
# Epoch 436/1000 - Avg Loss: 0.0004
# Epoch 441/1000 - Avg Loss: 0.0003
# Model saved as model_2025_04_19_01_16_0.000324_440.pth
# Epoch 446/1000 - Avg Loss: 0.0003
# Epoch 451/1000 - Avg Loss: 0.0004
# Epoch 456/1000 - Avg Loss: 0.0027
# Epoch 461/1000 - Avg Loss: 0.0003
# Model saved as model_2025_04_19_01_16_0.000333_460.pth
# Epoch 466/1000 - Avg Loss: 0.0003
# Epoch 471/1000 - Avg Loss: 0.0002
# Epoch 476/1000 - Avg Loss: 0.0002
# Epoch 481/1000 - Avg Loss: 0.0062
# Model saved as model_2025_04_19_01_16_0.006154_480.pth
# Epoch 486/1000 - Avg Loss: 0.0003
# Epoch 491/1000 - Avg Loss: 0.0002
# Epoch 496/1000 - Avg Loss: 0.0002
# Epoch 501/1000 - Avg Loss: 0.0002
# Model saved as model_2025_04_19_01_16_0.000175_500.pth
# Epoch 506/1000 - Avg Loss: 0.0002
# Epoch 511/1000 - Avg Loss: 0.0001
# Epoch 516/1000 - Avg Loss: 0.0045
# Epoch 521/1000 - Avg Loss: 0.0003
# Model saved as model_2025_04_19_01_16_0.000255_520.pth
# Epoch 526/1000 - Avg Loss: 0.0002
# Epoch 531/1000 - Avg Loss: 0.0002
# Epoch 536/1000 - Avg Loss: 0.0001
# Epoch 541/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000125_540.pth
# Epoch 546/1000 - Avg Loss: 0.0001
# Epoch 551/1000 - Avg Loss: 0.0204
# Epoch 556/1000 - Avg Loss: 0.0003
# Epoch 561/1000 - Avg Loss: 0.0002
# Model saved as model_2025_04_19_01_16_0.000188_560.pth
# Epoch 566/1000 - Avg Loss: 0.0001
# Epoch 571/1000 - Avg Loss: 0.0001
# Epoch 576/1000 - Avg Loss: 0.0001
# Epoch 581/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000098_580.pth
# Epoch 586/1000 - Avg Loss: 0.0001
# Epoch 591/1000 - Avg Loss: 0.0001
# Epoch 596/1000 - Avg Loss: 0.0011
# Epoch 601/1000 - Avg Loss: 0.0002
# Model saved as model_2025_04_19_01_16_0.000161_600.pth
# Epoch 606/1000 - Avg Loss: 0.0001
# Epoch 611/1000 - Avg Loss: 0.0001
# Epoch 616/1000 - Avg Loss: 0.0001
# Epoch 621/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000077_620.pth
# Epoch 626/1000 - Avg Loss: 0.0001
# Epoch 631/1000 - Avg Loss: 0.0001
# Epoch 636/1000 - Avg Loss: 0.0001
# Epoch 641/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000052_640.pth
# Epoch 646/1000 - Avg Loss: 0.0071
# Epoch 651/1000 - Avg Loss: 0.0002
# Epoch 656/1000 - Avg Loss: 0.0001
# Epoch 661/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000096_660.pth
# Epoch 666/1000 - Avg Loss: 0.0001
# Epoch 671/1000 - Avg Loss: 0.0001
# Epoch 676/1000 - Avg Loss: 0.0001
# Epoch 681/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000054_680.pth
# Epoch 686/1000 - Avg Loss: 0.0000
# Epoch 691/1000 - Avg Loss: 0.0000
# Epoch 696/1000 - Avg Loss: 0.0000
# Epoch 701/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000036_700.pth
# Epoch 706/1000 - Avg Loss: 0.0002
# Epoch 711/1000 - Avg Loss: 0.0001
# Epoch 716/1000 - Avg Loss: 0.0001
# Epoch 721/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000063_720.pth
# Epoch 726/1000 - Avg Loss: 0.0001
# Epoch 731/1000 - Avg Loss: 0.0000
# Epoch 736/1000 - Avg Loss: 0.0000
# Epoch 741/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000038_740.pth
# Epoch 746/1000 - Avg Loss: 0.0000
# Epoch 751/1000 - Avg Loss: 0.0000
# Epoch 756/1000 - Avg Loss: 0.0000
# Epoch 761/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000026_760.pth
# Epoch 766/1000 - Avg Loss: 0.0000
# Epoch 771/1000 - Avg Loss: 0.0000
# Epoch 776/1000 - Avg Loss: 0.0007
# Epoch 781/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000106_780.pth
# Epoch 786/1000 - Avg Loss: 0.0001
# Epoch 791/1000 - Avg Loss: 0.0001
# Epoch 796/1000 - Avg Loss: 0.0000
# Epoch 801/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000038_800.pth
# Epoch 806/1000 - Avg Loss: 0.0000
# Epoch 811/1000 - Avg Loss: 0.0000
# Epoch 816/1000 - Avg Loss: 0.0000
# Epoch 821/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000023_820.pth
# Epoch 826/1000 - Avg Loss: 0.0000
# Epoch 831/1000 - Avg Loss: 0.0000
# Epoch 836/1000 - Avg Loss: 0.0000
# Epoch 841/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000015_840.pth
# Epoch 846/1000 - Avg Loss: 0.0000
# Epoch 851/1000 - Avg Loss: 0.0000
# Epoch 856/1000 - Avg Loss: 0.0011
# Epoch 861/1000 - Avg Loss: 0.0001
# Model saved as model_2025_04_19_01_16_0.000077_860.pth
# Epoch 866/1000 - Avg Loss: 0.0001
# Epoch 871/1000 - Avg Loss: 0.0000
# Epoch 876/1000 - Avg Loss: 0.0000
# Epoch 881/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000027_880.pth
# Epoch 886/1000 - Avg Loss: 0.0000
# Epoch 891/1000 - Avg Loss: 0.0000
# Epoch 896/1000 - Avg Loss: 0.0000
# Epoch 901/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000016_900.pth
# Epoch 906/1000 - Avg Loss: 0.0000
# Epoch 911/1000 - Avg Loss: 0.0000
# Epoch 916/1000 - Avg Loss: 0.0000
# Epoch 921/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000011_920.pth
# Epoch 926/1000 - Avg Loss: 0.0000
# Epoch 931/1000 - Avg Loss: 0.0000
# Epoch 936/1000 - Avg Loss: 0.0000
# Epoch 941/1000 - Avg Loss: 0.0019
# Model saved as model_2025_04_19_01_16_0.001900_940.pth
# Epoch 946/1000 - Avg Loss: 0.0001
# Epoch 951/1000 - Avg Loss: 0.0001
# Epoch 956/1000 - Avg Loss: 0.0000
# Epoch 961/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000032_960.pth
# Epoch 966/1000 - Avg Loss: 0.0000
# Epoch 971/1000 - Avg Loss: 0.0000
# Epoch 976/1000 - Avg Loss: 0.0000
# Epoch 981/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000016_980.pth
# Epoch 986/1000 - Avg Loss: 0.0000
# Epoch 991/1000 - Avg Loss: 0.0000
# Epoch 996/1000 - Avg Loss: 0.0000
# Model saved as model_2025_04_19_01_16_0.000011.pth
# Plot saved as loss_plot_2025_04_19_01_16.png
# 29min 44s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
def evaluate_accuracy(dataloader, model, device="cuda"):
    model.eval()
    model.to(device)

    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, targets in dataloader:
            # Convert from numpy arrays to tensors if needed
            if isinstance(inputs, np.ndarray):
                inputs = torch.tensor(inputs, dtype=torch.float32)
            if isinstance(targets, np.ndarray):
                targets = torch.tensor(targets, dtype=torch.float32)

            inputs = inputs.to(device)       # shape: (B, T, C, H, W)
            targets = targets.to(device)     # shape: (B, 5)

            outputs = model(inputs)          # shape: (B, 5)
            predictions = (torch.sigmoid(outputs) > 0.5).float()  # apply sigmoid then threshold
            correct += (predictions == targets).sum().item()
            total += targets.numel()

    accuracy = correct / total * 100
    print(f"Accuracy: {accuracy:.2f}%")
    return accuracy

# %%
# Get a batch from the dataloader
inputs, targets = next(iter(val_dataloader))

# Check the shape of the inputs and targets
print(f"Inputs shape: {inputs.shape}")
print(f"Targets shape: {targets.shape}")
# Out:
# Inputs shape: torch.Size([64, 5, 5, 9, 18])
# Targets shape: torch.Size([64, 5])

# %%
accuracy = evaluate_accuracy(val_dataloader, model, device=device)
# Out:
# Accuracy: 4.89%

# %%
def extract_epoch(filename):
    match = re.search(r"_(\d+)\.pth$", filename)
    return int(match.group(1)) if match else -1

def evaluate_all_checkpoints(model_class, checkpoint_dir, train_loader, val_loader, device="cuda"):
    model_paths = sorted(glob.glob(f"./models/{checkpoint_dir}_*.pth"), key=extract_epoch)
    results = []
    best_val_acc = -1
    best_model_state = None

    for path in model_paths:
        epoch = extract_epoch(path)
        if epoch // 1 != epoch or epoch == -1:
            continue
        print(f"\nEvaluating model at epoch {epoch}...")

        # Initialize model and load state dict
        model = model_class()
        model.load_state_dict(torch.load(path, map_location=device))

        train_acc = evaluate_accuracy(train_loader, model, device)
        val_acc = evaluate_accuracy(val_loader, model, device)

        print(f"Epoch {epoch}: Train Acc = {train_acc:.2f}% | Val Acc = {val_acc:.2f}%")
        results.append((epoch, train_acc, val_acc))

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = model.state_dict()

    # Save the best model
    if best_model_state:
        best_path = f"./models/{checkpoint_dir}_best.pth"
        torch.save(best_model_state, best_path)
        print(f"\n✅ Best model saved to {best_path} with Val Acc = {best_val_acc:.2f}%")

    return results

# %%
def plot_accuracy_validation(results, save_path):
    # Unpack results
    epochs = [r[0] for r in results]
    train_accuracies = [r[1] for r in results]
    val_accuracies = [r[2] for r in results]

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_accuracies, label="Train Accuracy", marker='o', linestyle='-')
    plt.plot(epochs, val_accuracies, label="Validation Accuracy", marker='x', linestyle='--')
    plt.title("Model Accuracy Over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    # Save to file
    plt.savefig(save_path)
    plt.show()
    print(f"Accuracy plot saved to {save_path}")

# %%
# Define the directory and base filename pattern
file_path_test = "../data/test_data/cleaned_compiled_data_normalized.csv"

# Load and concatenate all parts
test_data = pd.read_csv(file_path_test)

# %%
test_dataset = LightningDataset_Modified(test_data,pixel_coords,reject_zeros=False)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=True, generator=g)

# %%
def evaluate_and_plot_checkpoints(model_class, checkpoint_dir, train_loader, val_loader, test_loader, device="cuda"):
    def extract_epoch(filename):
        match = re.search(r"_(\d+)\.pth$", filename)
        return int(match.group(1)) if match else -1

    model_paths = sorted(glob.glob(f"./models/{checkpoint_dir}_*.pth"), key=extract_epoch)
    results = []
    best_val_acc = -1
    best_model_state = None
    best_test_acc = -1

    for path in model_paths:
        epoch = extract_epoch(path)
        if epoch // 1 != epoch or epoch == -1:
            continue
        print(f"\n🔍 Evaluating model at epoch {epoch}...")

        # Initialize model and load weights
        model = model_class()
        model.load_state_dict(torch.load(path, map_location=device))

        # Evaluate on all splits
        train_acc = evaluate_accuracy(train_loader, model, device)
        val_acc = evaluate_accuracy(val_loader, model, device)
        test_acc = evaluate_accuracy(test_loader, model, device)

        print(f"Epoch {epoch}: Train Acc = {train_acc:.2f}% | Val Acc = {val_acc:.2f}% | Test Acc = {test_acc:.2f}%")
        results.append((epoch, train_acc, val_acc, test_acc))

        # Track best validation model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_test_acc = test_acc
            best_model_state = model.state_dict()

    # Save best model weights
    if best_model_state:
        best_model_path = f"./models/{checkpoint_dir}_best.pth"
        torch.save(best_model_state, best_model_path)
        print(f"\n✅ Best model saved to {best_model_path} with Val Acc = {best_val_acc:.2f}%")

        # Save best test accuracy
        test_acc_path = f"./models/{checkpoint_dir}_best_test.txt"
        with open(test_acc_path, "w") as f:
            f.write(f"Best Validation Accuracy: {best_val_acc:.2f}%\n")
            f.write(f"Test Accuracy at Best Val: {best_test_acc:.2f}%\n")
        print(f"✅ Test accuracy saved to {test_acc_path}")

    # --- Plotting ---
    if results:
        epochs = [r[0] for r in results]
        train_accuracies = [r[1] for r in results]
        val_accuracies = [r[2] for r in results]
        test_accuracies = [r[3] for r in results]

        plt.figure(figsize=(10, 6))
        plt.plot(epochs, train_accuracies, label="Train Accuracy", marker='o', linestyle='-')
        plt.plot(epochs, val_accuracies, label="Validation Accuracy", marker='x', linestyle='--')
        plt.plot(epochs, test_accuracies, label="Test Accuracy", marker='s', linestyle=':')
        plt.title("Model Accuracy Over Epochs")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy (%)")
        plt.grid(True)
        plt.legend()
        plt.tight_layout()

        # Save the plot
        plot_path = f"./models/{checkpoint_dir}_accuracy_plot.png"
        plt.savefig(plot_path)
        plt.show()
        print(f"📊 Accuracy plot saved to {plot_path}")

    return results

# %%
model_timestamp = "model_2025_04_18_20_46"

results = evaluate_and_plot_checkpoints(
    model_class=LightningRiskCNNRNN,
    checkpoint_dir=model_timestamp,  # Folder with .pth files
    train_loader=train_dataloader,
    val_loader=val_dataloader,test_loader = test_dataloader,
    device="cuda" if torch.cuda.is_available() else "cpu"
)
# Out:
# 🔍 Evaluating model at epoch 0...
# Accuracy: 10.87%
# Accuracy: 1.20%
# Accuracy: 7.04%
# Epoch 0: Train Acc = 10.87% | Val Acc = 1.20% | Test Acc = 7.04%
#
# 🔍 Evaluating model at epoch 20...
# Accuracy: 10.87%
# Accuracy: 1.20%
# Accuracy: 7.04%
# Epoch 20: Train Acc = 10.87% | Val Acc = 1.20% | Test Acc = 7.04%
#
# 🔍 Evaluating model at epoch 40...
# Accuracy: 10.87%
# Accuracy: 1.20%
# Accuracy: 7.04%
# Epoch 40: Train Acc = 10.87% | Val Acc = 1.20% | Test Acc = 7.04%
#
# 🔍 Evaluating model at epoch 60...
# Accuracy: 14.78%
# Accuracy: 1.69%
# Accuracy: 13.39%
# Epoch 60: Train Acc = 14.78% | Val Acc = 1.69% | Test Acc = 13.39%
#
# 🔍 Evaluating model at epoch 80...
# Accuracy: 18.68%
# Accuracy: 2.12%
# Accuracy: 15.54%
# Epoch 80: Train Acc = 18.68% | Val Acc = 2.12% | Test Acc = 15.54%
#
# 🔍 Evaluating model at epoch 100...
# Accuracy: 44.96%
# Accuracy: 4.91%
# Accuracy: 43.86%
# Epoch 100: Train Acc = 44.96% | Val Acc = 4.91% | Test Acc = 43.86%
#
# 🔍 Evaluating model at epoch 120...
# Accuracy: 32.30%
# Accuracy: 3.66%
# Accuracy: 31.76%
# Epoch 120: Train Acc = 32.30% | Val Acc = 3.66% | Test Acc = 31.76%
#
# 🔍 Evaluating model at epoch 140...
# Accuracy: 43.77%
# Accuracy: 4.91%
# Accuracy: 43.18%
# Epoch 140: Train Acc = 43.77% | Val Acc = 4.91% | Test Acc = 43.18%
#
# 🔍 Evaluating model at epoch 160...
# Accuracy: 45.36%
# Accuracy: 5.02%
# Accuracy: 46.01%
# Epoch 160: Train Acc = 45.36% | Val Acc = 5.02% | Test Acc = 46.01%
#
# 🔍 Evaluating model at epoch 180...
# Accuracy: 56.85%
# Accuracy: 6.30%
# Accuracy: 55.62%
# Epoch 180: Train Acc = 56.85% | Val Acc = 6.30% | Test Acc = 55.62%
#
# 🔍 Evaluating model at epoch 200...
# Accuracy: 33.65%
# Accuracy: 3.86%
# Accuracy: 32.02%
# Epoch 200: Train Acc = 33.65% | Val Acc = 3.86% | Test Acc = 32.02%
#
# 🔍 Evaluating model at epoch 220...
# Accuracy: 50.94%
# Accuracy: 5.77%
# Accuracy: 49.01%
# Epoch 220: Train Acc = 50.94% | Val Acc = 5.77% | Test Acc = 49.01%
#
# 🔍 Evaluating model at epoch 240...
# Accuracy: 61.21%
# Accuracy: 6.93%
# Accuracy: 60.43%
# Epoch 240: Train Acc = 61.21% | Val Acc = 6.93% | Test Acc = 60.43%
#
# 🔍 Evaluating model at epoch 260...
# Accuracy: 67.99%
# Accuracy: 7.70%
# Accuracy: 65.06%
# Epoch 260: Train Acc = 67.99% | Val Acc = 7.70% | Test Acc = 65.06%
#
# 🔍 Evaluating model at epoch 280...
# Accuracy: 48.73%
# Accuracy: 5.57%
# Accuracy: 50.04%
# Epoch 280: Train Acc = 48.73% | Val Acc = 5.57% | Test Acc = 50.04%
#
# 🔍 Evaluating model at epoch 300...
# Accuracy: 59.10%
# Accuracy: 6.72%
# Accuracy: 59.14%
# Epoch 300: Train Acc = 59.10% | Val Acc = 6.72% | Test Acc = 59.14%
#
# 🔍 Evaluating model at epoch 320...
# Accuracy: 66.00%
# Accuracy: 7.59%
# Accuracy: 65.41%
# Epoch 320: Train Acc = 66.00% | Val Acc = 7.59% | Test Acc = 65.41%
#
# 🔍 Evaluating model at epoch 340...
# Accuracy: 48.19%
# Accuracy: 5.72%
# Accuracy: 47.55%
# Epoch 340: Train Acc = 48.19% | Val Acc = 5.72% | Test Acc = 47.55%
#
# 🔍 Evaluating model at epoch 360...
# Accuracy: 58.24%
# Accuracy: 6.86%
# Accuracy: 56.31%
# Epoch 360: Train Acc = 58.24% | Val Acc = 6.86% | Test Acc = 56.31%
#
# 🔍 Evaluating model at epoch 380...
# Accuracy: 64.53%
# Accuracy: 7.56%
# Accuracy: 62.49%
# Epoch 380: Train Acc = 64.53% | Val Acc = 7.56% | Test Acc = 62.49%
#
# 🔍 Evaluating model at epoch 400...
# Accuracy: 70.37%
# Accuracy: 8.31%
# Accuracy: 68.76%
# Epoch 400: Train Acc = 70.37% | Val Acc = 8.31% | Test Acc = 68.76%
#
# 🔍 Evaluating model at epoch 420...
# Accuracy: 49.25%
# Accuracy: 5.84%
# Accuracy: 54.33%
# Epoch 420: Train Acc = 49.25% | Val Acc = 5.84% | Test Acc = 54.33%
#
# 🔍 Evaluating model at epoch 440...
# Accuracy: 58.71%
# Accuracy: 6.89%
# Accuracy: 62.06%
# Epoch 440: Train Acc = 58.71% | Val Acc = 6.89% | Test Acc = 62.06%
#
# 🔍 Evaluating model at epoch 460...
# Accuracy: 65.74%
# Accuracy: 7.64%
# Accuracy: 66.70%
# Epoch 460: Train Acc = 65.74% | Val Acc = 7.64% | Test Acc = 66.70%
#
# 🔍 Evaluating model at epoch 480...
# Accuracy: 45.42%
# Accuracy: 5.31%
# Accuracy: 50.64%
# Epoch 480: Train Acc = 45.42% | Val Acc = 5.31% | Test Acc = 50.64%
#
# ✅ Best model saved to ./models/model_2025_04_18_20_46_best.pth with Val Acc = 8.31%
# ✅ Test accuracy saved to ./models/model_2025_04_18_20_46_best_test.txt
# 📊 Accuracy plot saved to ./models/model_2025_04_18_20_46_accuracy_plot.png

# %%
def safe_sigmoid(x):
    # If all outputs are already in [0, 1], assume sigmoid already applied
    if x.min() >= 0 and x.max() <= 1:
        return x  # Already probabilities
    return torch.sigmoid(x)  # Assume logits

def evaluate_metrics(dataloader, model, device="cuda"):
    model.eval()
    model.to(device)
    all_preds, all_targets = [], []

    with torch.no_grad():
        for inputs, targets in dataloader:
            # Convert from NumPy if needed
            if isinstance(inputs, np.ndarray):
                inputs = torch.tensor(inputs)
            if isinstance(targets, np.ndarray):
                targets = torch.tensor(targets)

            inputs = inputs.to(device)
            targets = targets.to(device)

            outputs = model(inputs)
            
            probs = safe_sigmoid(outputs)
            preds = (probs > 0.5).int()

            all_preds.append(preds.cpu())
            all_targets.append(targets.cpu())

    all_preds = torch.cat(all_preds).numpy()
    all_targets = torch.cat(all_targets).numpy()

    accuracy = (all_preds == all_targets).mean() * 100
    precision = precision_score(all_targets, all_preds, average="macro", zero_division=0)
    recall = recall_score(all_targets, all_preds, average="macro", zero_division=0)
    f1 = f1_score(all_targets, all_preds, average="macro", zero_division=0)

    return accuracy, precision, recall, f1

# %%
def evaluate_all_checkpoints(model_class, checkpoint_dir, train_loader, val_loader, test_loader, device="cuda"):
    import os, glob
    import matplotlib.pyplot as plt
    import torch

    model_paths = sorted(glob.glob(f"./models/{checkpoint_dir}_*.pth"), key=extract_epoch)
    results = []

    best_val_f1 = -1
    best_model_state = None

    for path in model_paths:
        epoch = extract_epoch(path)
        if epoch == -1:
            continue
        print(f"\nEvaluating model at epoch {epoch}...")

        model = model_class()
        model.load_state_dict(torch.load(path, map_location=device))
        model.to(device)
        model.eval()

        train_metrics = evaluate_metrics(train_loader, model, device)
        val_metrics = evaluate_metrics(val_loader, model, device)
        test_metrics = evaluate_metrics(test_loader, model, device)

        print(f"Epoch {epoch}:")
        print(f"  Train Acc: {train_metrics[0]:.2f}% | F1: {train_metrics[3]:.4f}")
        print(f"  Val Acc  : {val_metrics[0]:.2f}% | F1: {val_metrics[3]:.4f}")
        print(f"  Test Acc : {test_metrics[0]:.2f}% | F1: {test_metrics[3]:.4f}")

        results.append((epoch, *train_metrics, *val_metrics, *test_metrics))

        if val_metrics[3] > best_val_f1:
            best_val_f1 = val_metrics[3]
            best_model_state = model.state_dict()

    # Save best model
    if best_model_state:
        best_path = f"./models/{checkpoint_dir}_best_{val_metrics[3]}.pth"
        torch.save(best_model_state, best_path)
        print(f"\n✅ Best model saved to {best_path} with Val F1 = {best_val_f1:.4f}")

    # Extract metrics
    epochs = [r[0] for r in results]
    train_accs = [r[1] for r in results]
    train_f1s = [r[4] for r in results]
    val_accs = [r[5] for r in results]
    val_f1s = [r[8] for r in results]
    test_accs = [r[9] for r in results]
    test_f1s = [r[12] for r in results]

    # Plotting
    fig, axs = plt.subplots(1, 2, figsize=(16, 6))

    # Accuracy Plot
    axs[0].plot(epochs, train_accs, label="Train Accuracy", color="blue", marker="o")
    axs[0].plot(epochs, val_accs, label="Val Accuracy", color="green", marker="s")
    axs[0].plot(epochs, test_accs, label="Test Accuracy", color="teal", marker="^")
    axs[0].set_title("Accuracy over Epochs")
    axs[0].set_xlabel("Epoch")
    axs[0].set_ylabel("Accuracy (%)")
    axs[0].legend()
    axs[0].grid(True)

    # F1 Score Plot
    axs[1].plot(epochs, train_f1s, label="Train F1", color="purple", marker="o")
    axs[1].plot(epochs, val_f1s, label="Val F1", color="orange", marker="s")
    axs[1].plot(epochs, test_f1s, label="Test F1", color="red", marker="^")
    axs[1].set_title("F1 Score over Epochs")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("F1 Score")
    axs[1].legend()
    axs[1].grid(True)

    plt.tight_layout()
    os.makedirs("plots", exist_ok=True)
    plot_filename = f"./plots/metrics_{checkpoint_dir}.png"
    plt.savefig(plot_filename)
    print(f"\n📈 Metrics plot saved to {plot_filename}")
    plt.show()

    return results

# %%
model_timestamp = "model_2025_04_19_01_16"

results = evaluate_all_checkpoints(
    model_class=LightningRiskCNNRNN,
    checkpoint_dir=model_timestamp,  # Folder with .pth files
    train_loader=train_dataloader,
    val_loader=val_dataloader,
    test_loader = test_dataloader,
    device="cuda" if torch.cuda.is_available() else "cpu"
)
# Out:
# Evaluating model at epoch 0...
# Epoch 0:
#   Train Acc: 90.70% | F1: 0.0000
#   Val Acc  : 97.36% | F1: 0.0000
#   Test Acc : 92.96% | F1: 0.0000
#
# Evaluating model at epoch 20...
# Epoch 20:
#   Train Acc: 90.70% | F1: 0.0000
#   Val Acc  : 97.36% | F1: 0.0000
#   Test Acc : 92.96% | F1: 0.0000
#
# Evaluating model at epoch 40...
# Epoch 40:
#   Train Acc: 91.14% | F1: 0.0811
#   Val Acc  : 97.50% | F1: 0.0848
#   Test Acc : 93.13% | F1: 0.0800
#
# Evaluating model at epoch 60...
# Epoch 60:
#   Train Acc: 91.54% | F1: 0.1348
#   Val Acc  : 97.59% | F1: 0.1244
#   Test Acc : 93.48% | F1: 0.1333
#
# Evaluating model at epoch 80...
# Epoch 80:
#   Train Acc: 91.95% | F1: 0.1976
#   Val Acc  : 97.65% | F1: 0.1677
#   Test Acc : 93.22% | F1: 0.1407
#
# Evaluating model at epoch 100...
# Epoch 100:
#   Train Acc: 92.29% | F1: 0.2440
#   Val Acc  : 97.69% | F1: 0.1884
#   Test Acc : 92.19% | F1: 0.1303
#
# Evaluating model at epoch 120...
# Epoch 120:
#   Train Acc: 93.06% | F1: 0.3682
#   Val Acc  : 97.83% | F1: 0.2902
#   Test Acc : 90.99% | F1: 0.2620
#
# Evaluating model at epoch 140...
# Epoch 140:
#   Train Acc: 93.50% | F1: 0.4307
#   Val Acc  : 97.79% | F1: 0.2965
#   Test Acc : 90.04% | F1: 0.2708
#
# Evaluating model at epoch 160...
# Epoch 160:
#   Train Acc: 95.37% | F1: 0.6590
#   Val Acc  : 97.90% | F1: 0.4255
#   Test Acc : 83.69% | F1: 0.2334
#
# Evaluating model at epoch 180...
# Epoch 180:
#   Train Acc: 95.96% | F1: 0.7152
#   Val Acc  : 97.94% | F1: 0.4603
#   Test Acc : 79.66% | F1: 0.2554
#
# Evaluating model at epoch 200...
# Epoch 200:
#   Train Acc: 96.98% | F1: 0.8027
#   Val Acc  : 98.00% | F1: 0.5125
#   Test Acc : 75.71% | F1: 0.2704
#
# Evaluating model at epoch 220...
# Epoch 220:
#   Train Acc: 98.10% | F1: 0.8833
#   Val Acc  : 97.94% | F1: 0.5290
#   Test Acc : 71.76% | F1: 0.2433
#
# Evaluating model at epoch 240...
# Epoch 240:
#   Train Acc: 98.51% | F1: 0.9126
#   Val Acc  : 98.02% | F1: 0.5513
#   Test Acc : 69.53% | F1: 0.2150
#
# Evaluating model at epoch 260...
# Epoch 260:
#   Train Acc: 99.10% | F1: 0.9492
#   Val Acc  : 98.02% | F1: 0.5586
#   Test Acc : 67.12% | F1: 0.2082
#
# Evaluating model at epoch 280...
# Epoch 280:
#   Train Acc: 99.58% | F1: 0.9772
#   Val Acc  : 98.03% | F1: 0.5848
#   Test Acc : 65.32% | F1: 0.2284
#
# Evaluating model at epoch 300...
# Epoch 300:
#   Train Acc: 99.50% | F1: 0.9721
#   Val Acc  : 98.01% | F1: 0.5627
#   Test Acc : 66.87% | F1: 0.2415
#
# Evaluating model at epoch 320...
# Epoch 320:
#   Train Acc: 99.77% | F1: 0.9877
#   Val Acc  : 97.98% | F1: 0.5686
#   Test Acc : 65.67% | F1: 0.2310
#
# Evaluating model at epoch 340...
# Epoch 340:
#   Train Acc: 99.89% | F1: 0.9942
#   Val Acc  : 97.99% | F1: 0.5793
#   Test Acc : 65.49% | F1: 0.2180
#
# Evaluating model at epoch 360...
# Epoch 360:
#   Train Acc: 99.94% | F1: 0.9969
#   Val Acc  : 98.00% | F1: 0.5800
#   Test Acc : 65.58% | F1: 0.2270
#
# Evaluating model at epoch 380...
# Epoch 380:
#   Train Acc: 99.96% | F1: 0.9981
#   Val Acc  : 97.98% | F1: 0.5805
#   Test Acc : 65.06% | F1: 0.2179
#
# Evaluating model at epoch 400...
# Epoch 400:
#   Train Acc: 99.96% | F1: 0.9980
#   Val Acc  : 97.97% | F1: 0.5766
#   Test Acc : 64.72% | F1: 0.2103
#
# Evaluating model at epoch 420...
# Epoch 420:
#   Train Acc: 100.00% | F1: 0.9998
#   Val Acc  : 97.99% | F1: 0.5840
#   Test Acc : 65.32% | F1: 0.2188
#
# Evaluating model at epoch 440...
# Epoch 440:
#   Train Acc: 99.99% | F1: 0.9997
#   Val Acc  : 97.92% | F1: 0.5684
#   Test Acc : 65.92% | F1: 0.2269
#
# Evaluating model at epoch 460...
# Epoch 460:
#   Train Acc: 99.99% | F1: 0.9996
#   Val Acc  : 97.97% | F1: 0.5776
#   Test Acc : 64.12% | F1: 0.2177
#
# Evaluating model at epoch 480...
# Epoch 480:
#   Train Acc: 99.06% | F1: 0.9471
#   Val Acc  : 97.98% | F1: 0.5535
#   Test Acc : 69.36% | F1: 0.2122
#
# Evaluating model at epoch 500...
# Epoch 500:
#   Train Acc: 100.00% | F1: 0.9998
#   Val Acc  : 97.95% | F1: 0.5739
#   Test Acc : 65.49% | F1: 0.2425
#
# Evaluating model at epoch 520...
# Epoch 520:
#   Train Acc: 100.00% | F1: 0.9998
#   Val Acc  : 97.96% | F1: 0.5643
#   Test Acc : 63.86% | F1: 0.2037
#
# Evaluating model at epoch 540...
# Epoch 540:
#   Train Acc: 100.00% | F1: 0.9998
#   Val Acc  : 97.95% | F1: 0.5684
#   Test Acc : 64.55% | F1: 0.2224
#
# Evaluating model at epoch 560...
# Epoch 560:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.99% | F1: 0.5841
#   Test Acc : 64.89% | F1: 0.2230
#
# Evaluating model at epoch 580...
# Epoch 580:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.97% | F1: 0.5821
#   Test Acc : 64.21% | F1: 0.2280
#
# Evaluating model at epoch 600...
# Epoch 600:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.99% | F1: 0.5852
#   Test Acc : 64.46% | F1: 0.2106
#
# Evaluating model at epoch 620...
# Epoch 620:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.98% | F1: 0.5848
#   Test Acc : 64.55% | F1: 0.2088
#
# Evaluating model at epoch 640...
# Epoch 640:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.96% | F1: 0.5835
#   Test Acc : 64.64% | F1: 0.2183
#
# Evaluating model at epoch 660...
# Epoch 660:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.97% | F1: 0.5804
#   Test Acc : 65.58% | F1: 0.2212
#
# Evaluating model at epoch 680...
# Epoch 680:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.96% | F1: 0.5772
#   Test Acc : 65.06% | F1: 0.2107
#
# Evaluating model at epoch 700...
# Epoch 700:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5758
#   Test Acc : 64.72% | F1: 0.2153
#
# Evaluating model at epoch 720...
# Epoch 720:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5796
#   Test Acc : 63.95% | F1: 0.1987
#
# Evaluating model at epoch 740...
# Epoch 740:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.96% | F1: 0.5799
#   Test Acc : 64.55% | F1: 0.2113
#
# Evaluating model at epoch 760...
# Epoch 760:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.96% | F1: 0.5794
#   Test Acc : 65.49% | F1: 0.2272
#
# Evaluating model at epoch 780...
# Epoch 780:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.91% | F1: 0.5735
#   Test Acc : 64.72% | F1: 0.2074
#
# Evaluating model at epoch 800...
# Epoch 800:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5817
#   Test Acc : 63.95% | F1: 0.2120
#
# Evaluating model at epoch 820...
# Epoch 820:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5772
#   Test Acc : 63.95% | F1: 0.2179
#
# Evaluating model at epoch 840...
# Epoch 840:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.93% | F1: 0.5734
#   Test Acc : 63.86% | F1: 0.2161
#
# Evaluating model at epoch 860...
# Epoch 860:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.92% | F1: 0.5716
#   Test Acc : 64.38% | F1: 0.2250
#
# Evaluating model at epoch 880...
# Epoch 880:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5765
#   Test Acc : 64.29% | F1: 0.2277
#
# Evaluating model at epoch 900...
# Epoch 900:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.95% | F1: 0.5800
#   Test Acc : 63.52% | F1: 0.2163
#
# Evaluating model at epoch 920...
# Epoch 920:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.94% | F1: 0.5773
#   Test Acc : 63.61% | F1: 0.2147
#
# Evaluating model at epoch 940...
# Epoch 940:
#   Train Acc: 99.83% | F1: 0.9910
#   Val Acc  : 97.97% | F1: 0.5703
#   Test Acc : 67.55% | F1: 0.2108
#
# Evaluating model at epoch 960...
# Epoch 960:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.96% | F1: 0.5768
#   Test Acc : 65.75% | F1: 0.2071
#
# Evaluating model at epoch 980...
# Epoch 980:
#   Train Acc: 100.00% | F1: 1.0000
#   Val Acc  : 97.99% | F1: 0.5820
#   Test Acc : 65.84% | F1: 0.2179
#
# ✅ Best model saved to ./models/model_2025_04_19_01_16_best_0.5819965169496033.pth with Val F1 = 0.5852
#
# 📈 Metrics plot saved to ./plots/metrics_model_2025_04_19_01_16.png
